# %% [markdown]
# <a href="https://colab.research.google.com/github/nishantparmar24/Political-Risk/blob/master/DataResource.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sentiment Analysis - Twitter

# %% [markdown]
# ### Install required packages

# %%
# !pip install searchtweets unidecode newsapi-python
# Out:
# Collecting searchtweets
#   Downloading https://files.pythonhosted.org/packages/51/d7/7dd296ba9469e046bad23583aaa0d36b18c7d6e4df9fd2acfb433d1c7ee2/searchtweets-1.7.4-py3-none-any.whl
# Collecting unidecode
#   Downloading https://files.pythonhosted.org/packages/d0/42/d9edfed04228bacea2d824904cae367ee9efd05e6cce7ceaaedd0b0ad964/Unidecode-1.1.1-py2.py3-none-any.whl (238kB)
#      |████████████████████████████████| 245kB 12.7MB/s
# Collecting newsapi-python
#   Downloading https://files.pythonhosted.org/packages/4a/49/cbb39846c53076a1cde2c73c5dbc3d39956ea7586c8dfc35d516d706a497/newsapi-python-0.2.5.tar.gz
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from searchtweets) (3.13)
# Collecting tweet-parser
#   Downloading https://files.pythonhosted.org/packages/4b/ea/cb82efb43dbcb115ea447313fbd287ff66349b34bdfdb4a78e25d3a42cb0/tweet_parser-1.13.2-py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from searchtweets) (2.21.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (2019.9.11)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->searchtweets) (1.24.3)
# Building wheels for collected packages: newsapi-python
#   Building wheel for newsapi-python (setup.py) ... done
#   Created wheel for newsapi-python: filename=newsapi_python-0.2.5-py2.py3-none-any.whl size=6593 sha256=40d8b88115d90a39582d27dc6229876b633693eeb7a18bac24c8178b42cf7885
#   Stored in directory: /root/.cache/pip/wheels/d8/dc/5e/857ef20410a023cfe728ac6f360958df44b199b459cbc6ccbc
# Successfully built newsapi-python
# Installing collected packages: tweet-parser, searchtweets, unidecode, newsapi-python
# Successfully installed newsapi-python-0.2.5 searchtweets-1.7.4 tweet-parser-1.13.2 unidecode-1.1.1

# %% [markdown]
# ### Import all required packages

# %%
from datetime import datetime as dt
from google.cloud import translate
from google.colab import drive
from html import unescape
from newsapi import NewsApiClient
from numpy import nan
from searchtweets import load_credentials, gen_rule_payload, collect_results
from time import sleep
from unidecode import unidecode
from urllib import parse
import json
import os
import pandas as pd
import re
import requests
import unicodedata

# %% [markdown]
# ### Enable Google Drive in this notebook:

# %%
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
DRIVE_LOCATION = "/gdrive/My Drive/Political Risk Project/Test Data"
SEARCH_RESULTS = "/gdrive/My Drive/Firebolt/Political Risk"
bckp_loc = "/gdrive/My Drive/Political Risk Project/Test Data/Backup"

search_results = os.path.join(SEARCH_RESULTS, 'new_outputs.csv')
tw_output_directory = os.path.join(DRIVE_LOCATION, 'Twitter Results')
nh_output_directory = os.path.join(DRIVE_LOCATION, 'News Results')
Twitter_API_usage_file = os.path.join(tw_output_directory, 'api_usage.json')
News_API_usage_file = os.path.join(nh_output_directory, 'api_usage.json')

# %% [markdown]
# ### Fetch Google Translate API credentials

# %%
translate_api_dir = "/gdrive/My Drive/Firebolt/API Keys"
translate_api_key = os.path.join(translate_api_dir, 'eiu-searchautomation.json')
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = translate_api_key
try:
    translate_client = translate.Client()
    
    def translate_keyword(keyword, target_lang="en"):
        response = translate_client.translate(keyword,
                                              target_language=target_lang)
        if response:
            return response["translatedText"]
        else:
            return ""
    
    def detect_language(text_string):
        result = translate_client.detect_language(text_string)
        return result["language"]
    
except Exception as e:
    print("Exception occurred while instantiating \
    Google Cloud Translate: {}".format(e))

# %% [markdown]
# ### Get text with the least length from a collection of text values

# %%
def phrase_min_length(text_sample):
    sample_df = pd.DataFrame(text_sample, columns=['text'])
    sample_df["length"] = [l for l in map(len, text_sample)]
    min_pos = sample_df["length"] == sample_df["length"].min()
    min_phrase = sample_df[min_pos]["text"]

# %% [markdown]
# ### Function to remove emojis from a text string

# %%
def remove_emojis(input_string):
    return_string = ""

    for character in input_string.strip():
        try:
            character.encode("ascii")
            return_string += character
        except UnicodeEncodeError:
            replaced = unidecode(str(character))
            if replaced not in ['', '[?]']:
                return_string += replaced
    return return_string.strip()

# %% [markdown]
# ### Function to extract (and segregate) tweet-components: links, user-handles and hashtags

# %%
def extract_components(clean_string):
    token_list = re.split(r"\s+", clean_string.strip())
    url_ptrn = '^https?:\/\/.*[\r\n]*'
    handle_ptrn = '^\@.*'
    trend_ptrn = '^#.*'
    url_collection = list()
    handle_collection = list()
    trend_collection = list()
    tokens = list()
    for token in token_list:
        # print("token = {}".format(token))
        url_match = re.search(url_ptrn, token) or re.match(url_ptrn, token)
        if url_match:
            # print("\t\tURL Pattern matched")
            url_collection.append(
                token) if token not in url_collection else False
            ix = token_list.index(token)
            token_list[ix] = ''
            continue
        handle_match = re.search(
            handle_ptrn, token) or re.match(handle_ptrn, token)
        if handle_match:
            # print("\t\tHandle Pattern matched")
            handle_collection.append(
                token) if token not in handle_collection else False
            ix = token_list.index(token)
            token_list[ix] = ''
            continue
        trend_match = re.search(
            trend_ptrn, token) or re.match(trend_ptrn, token)
        if trend_match:
            # print("\t\tTrend Pattern matched")
            trend_collection.append(
                token) if token not in trend_collection else False
            ix = token_list.index(token)
            token_list[ix] = ''
            continue
        if token.strip():
            tokens.append(token)
    del token_list
    return (tokens, url_collection, handle_collection, trend_collection)

# %% [markdown]
# ### Function to clean and structure the text data

# %%
def structure_text(entire_str):
    separations = dict()
    clean_str = remove_emojis(entire_str)
    tokens, links, handles, tags = extract_components(clean_str)
    clean_str = (" ".join(tokens)).strip()
    print("clean_str = {}".format(clean_str))
    cleaner_str = (re.subn("[:-]+", "", clean_str))[0].strip()
    try:
        cleaner_str = unescape(translate_keyword(cleaner_str))
    except Exception as e:
        print("Exception occurred: {}".format(e))
        sleep(5)
        try:
            cleaner_str = unescape(translate_keyword(cleaner_str))
        except Exception as e:
            cleaner_str = ""
    print("cleaner_str = {}".format(cleaner_str))
    separations['text'] = cleaner_str
    separations['links'] = ",".join(links)
    separations['handles'] = ",".join(handles)
    separations['tags'] = ",".join(tags)
    return separations

# %% [markdown]
# ### Function to include a zero for date values less than 10

# %%
format_date_str = lambda s: "0{}".format(s) if int(s) < 10 else "{}".format(s)

# %% [markdown]
# ### Function to return a formatting of current datetime (for file names)

# %%
today = lambda: "{}-{}-{}_{}-{}".format(dt.now().year,
                                format_date_str(dt.now().month),
                                format_date_str(dt.now().day),
                                format_date_str(dt.now().hour),
                                format_date_str(dt.now().minute))
today_date = today().split("_")[0]
today_date
# Out:
# '2019-11-28'

# %% [markdown]
# ### Function to format datetime as string (time separated with a ":")

# %%
def extract_datetime_string(datetime_obj):
    if datetime_obj:
        return "{}-{}-{} {}:{}:{}".format(datetime_obj.year,
                                          format_date_str(datetime_obj.month),
                                          format_date_str(datetime_obj.day),
                                          format_date_str(datetime_obj.hour),
                                          format_date_str(datetime_obj.minute),
                                          format_date_str(datetime_obj.second))

# %% [markdown]
# ### Functions to create and validate custom dates

# %%
def get_month_days_map(year, month=None):
    month_days_map = {(1, 3, 5, 7, 8, 10, 12): 31, (4, 6, 9, 11): 30}
    if year % 4 == 0:
        month_days_map.update({(2,): 29})
    else:
        month_days_map.update({(2,): 28})
    month = 12 if month == 0 else month
    if month:
        for months, n_days in month_days_map.items():
            if month in months:
                return n_days
    return month_days_map

# %%
def validate_custom_date(year, month, day):
    print("Date entered: {}-{}-{}".format(year, 
                                          format_date_str(month), 
                                          format_date_str(day)))
    n_days = get_month_days_map(year, month=month)
    if month not in range(1, 13):
        print("Invalid month entered!")
        return False
    if day not in range(1, n_days+1):
        print("Invalid day entered!")
        return False
    if year > dt.now().year and month > dt.now().month and day > dt.now().day:
        print("Wrong date entered! Please enter correct date values.")
        return False
    elif year > dt.now().year:
        print("Invalid year entered!")
        return False
    elif year == dt.now().year:
        if month > dt.now().month:
            print("Invalid month entered!")
            return False
        if day > dt.now().day:
            print("Invalid day entered!")
            return False
    return True

# %%
def get_custom_date(year=dt.now().year, month=dt.now().month, day=dt.now().day):
    date_valid = validate_custom_date(year, month, day)
    custom_date = ""
    if date_valid:
        from_day = diff_day = day - 7
        from_mon = month
        from_year = year
        prev_n = get_month_days_map(year, month - 1)
        if diff_day < 0:
            from_day = diff_day % prev_n
            from_mon = month - 1 if month != 1 else 12 
            from_year = year - 1 if month == 1 else year
        elif diff_day == 0:
            from_day = prev_n
            from_mon = month - 1 if month != 1 else 12
            from_year = year - 1 if month == 1 else year
        print("from_day = {}".format(from_day))
        custom_date = "{}-{}-{}".format(from_year, 
                                        format_date_str(from_mon), 
                                        format_date_str(from_day)) 
    return custom_date

get_custom_date()
# Out:
# Date entered: 2019-11-28
# from_day = 21
# '2019-11-21'

# %% [markdown]
# ### Fetch Twitter Premium Search API credentials

# %%
creds_file = '/gdrive/My Drive/Political Risk Project/TwitterCredentials/Bckp/twitter_creds.yaml'
search_tweets_api = 'search_tweets_30_day_dev'
premium_search_args = load_credentials(filename=creds_file,
                                       yaml_key=search_tweets_api,
                                       env_overwrite=False)
# Out:
# Grabbing bearer token from OAUTH

# %% [markdown]
# ### Defining all the filters, queries and user handles

# %%
it_query_filter = "-has:media place_country:IT"
it_en_query_filter = "-has:media place_country:IT lang:en"
generic_query_filter = "-has:media"
queries = ["early election", "snap election", "government collapse", 
           "government coalition", "election", "instability", "uncertainty",
           "crisis", "coalition"]
queries_it = [q for q in map(lambda s: translate_keyword(s, "it"), queries)]

from_users = ["lorepregliasco", "FerdiGiugliano", "AlbertoNardelli", 
              "gavinjones10"]

# %%
# print(queries)
# print(queries_it)
# Out:
# ['early election',
#  'snap election',
#  'government collapse',
#  'government coalition',
#  'election',
#  'instability',
#  'uncertainty',
#  'crisis',
#  'coalition',
#  'elezioni anticipate',
#  'elezioni anticipate',
#  'crollo del governo',
#  'coalizione di governo',
#  'elezione',
#  'instabilità',
#  'incertezza',
#  'crisi',
#  'coalizione']

# %% [markdown]
# ### Twitter API Usage Monitor

# %%
def get_api_usage(date):
    if os.path.lexists(Twitter_API_usage_file):
        api_usage = pd.read_json(Twitter_API_usage_file, orient='records')
        print(api_usage)
        print(list(api_usage.columns))
        if date in api_usage.columns:
            return api_usage, api_usage[date].squeeze()
        else:
            # update_api_count(date, 0)
            return api_usage, 0
    return None, None


def update_api_count(date, count_add):
    api_usage, count = get_api_usage(date)
    if not api_usage.empty:
        updated_count = 0
        print(list(api_usage.columns))
        if date in api_usage.columns:
            print("Month present\n")
            api_usage[date] += count_add
            updated_count = api_usage[date].squeeze()
        else:
            print("Month absent\n")
            api_usage[date] = 1
        print("api_usage = {}".format(api_usage[date]))
        api_usage.to_json(Twitter_API_usage_file, 
                          orient='records', 
                          date_format='iso')
        sleep(3)
        print("Updating new API usage...")
        _, new_count = get_api_usage(date)
        if new_count != updated_count:
            print("...")
            drive.mount("/gdrive", force_remount=True)
        _, new_count = get_api_usage(date)
        # print(new_count)
        # while new_count != updated_count:
        #     print("Updating new API usage...")
        #     _, new_count = get_api_usage(date)
        print("API usage count updated! Current usage: {}".format(new_count))

# %% [markdown]
# ### NewsAPI Usage Monitor

# %%
def get_news_api_usage(date):
    if os.path.lexists(News_API_usage_file):
        api_usage = pd.read_json(News_API_usage_file, orient="records")
        if date in api_usage.columns:
            return api_usage, api_usage[date].squeeze()
        else:
            # update_news_api_count(date)
            return api_usage, 1
    return None, None


def update_news_api_count(date):
    api_usage, count = get_news_api_usage(date)
    if not api_usage.empty:
        updated_count = 0
        if date in api_usage.columns:
            api_usage[date] += 1
            updated_count = api_usage[date].squeeze()
        else:
            api_usage[date] = 0
        api_usage.to_json(News_API_usage_file, orient="records", date_format="iso")
        sleep(3)
        _, new_count = get_news_api_usage(date)
        print("Updating new API usage...")
        # print(new_count)
        if new_count != updated_count:
            print("...")
            drive.mount("/gdrive", force_remount=True)
        _, new_count = get_news_api_usage(date)
        print("API usage count updated! Current usage: {}".format(new_count))

# %% [markdown]
# ### Fetch NewsAPI Credentials

# %%
def get_api_key():
    src_ = "/gdrive/My Drive/Political Risk Project/NewsAPIKey/"
    with open(os.path.join(src_, "news_api_key.json")) as key:
        obj = json.load(key)
        return obj["api_key"]


newsapi = NewsApiClient(api_key=get_api_key())

# %% [markdown]
# ### Initialize News API variables

# %%
news_sources = ",".join(["reuters", "ansa", "google-news-it"])
print(news_sources)
# queries = ["early election", "snap election", "government collapse", 
#            "government coalition", "election", "instability", "uncertainty",
#            "crisis", "coalition"]
country = "it"
page_size = 100
endpoint = "everything" # "top-headlines"
# Out:
# reuters,ansa,google-news-it

# %% [markdown]
# ### Fetch News Headlines using the News API

# %%
def fetch_news(queries, sources, page_size=100, **kwargs):
    top_headlines_map = dict()
    # saved_files = list()
    news_collection = pd.DataFrame()
    for query in queries:
        headlines = newsapi.get_everything(q=query,
                                           sources=sources,
                                           sort_by="relevancy",
                                           page_size=page_size)
        if headlines["totalResults"] > 0:
            # response_text = json.loads(headlines.text)
            all_articles = headlines["articles"]
            collection = list()
            for article in all_articles:
                data_ = dict()
                source = article.pop("source")
                content = article.pop("content")
                source = {"source": source["id"]}
                article.update(source)
                collection.append(article)
            data_df = pd.DataFrame(data=collection)
            if not data_df.empty:
                match_str = "({})".format(query)
                reqd_df = data_df[data_df["description"].str.contains(
                    match_str)]
                if news_collection.empty:
                    news_collection = reqd_df
                else:
                    news_collection = news_collection.append(reqd_df)
                # responses_file = "{}_on_{}.csv".format(endpoint,
                #                                       query.replace(" ", "_"))
                # top_headlines_map[query] = reqd_df
            
                # out_file = os.path.join(output_directory, responses_file)
                # data_df.to_csv(out_file, index=False)
            update_news_api_count(today())
    return news_collection

# %% [markdown]
# ### Functions to fetch tweets by querying the Twitter API with the given queries and filters

# %%
def get_user_queries_filter(queries, from_users):
    user_queries_filter = '("{}") from:{} -has:media'
    user_queries_list = list()
    for query in queries:
        for user in from_users:
            filter_ = user_queries_filter.format(query, user)
            user_queries_list.append(filter_)
    return user_queries_list


def get_user_specific_filter(from_users):
    user_specific_filter =  'from:{} -has:media'
    user_specific_list = list()
    # for query in queries:
    for user in from_users:
        filter_ = user_specific_filter.format(user)
        user_specific_list.append(filter_)
    return user_specific_list


def get_tweets(query_set, query_filter=None):
    tweets_list = list()
    for query in query_set:
        curr_month = "{}-{}".format(dt.now().year, 
                                    format_date_str(dt.now().month))
        _, curr_usage = get_api_usage(curr_month)
        if curr_usage >= 24999:
            print("Twitter API limit is about to exceed! Returning now ...\n")
            break
        if query_filter:
            q = '("{}") {}'.format(query, query_filter)
        else:
            q = "{}".format(query)
            print("No filter/Filter in query_set: {}".format(q))
        print("Collecting for {}".format(q))
        try:
            rule = gen_rule_payload(q, results_per_call=100)
            tweets = collect_results(rule,
                                    max_results=100,
                                    result_stream_args=premium_search_args)
            print(len(tweets))
            update_api_count(curr_month, len(tweets))
            tweets_list.append(tweets)

        except Exception as e:
            print("Exception occurred while fetching tweets: {}".format(e))
            break
    return tweets_list

# %%
user_specific_queries = get_user_specific_filter(from_users)
user_specific_queries
# Out:
# ['from:lorepregliasco -has:media',
#  'from:FerdiGiugliano -has:media',
#  'from:AlbertoNardelli -has:media',
#  'from:gavinjones10 -has:media']

# %% [markdown]
# ### Process the tweets to produce a collection of tweet-text, hashtags, links, and the date-time when they were created.

# %%
def process_tweets(tweets_list):
    tweets_collection = pd.DataFrame()
    for tweets in tweets_list:
        for tweet in tweets:
            structured_tweets = structure_text(tweet.all_text)
            structured_tweets.update({"created_time":tweet.created_at_datetime})
            reqd_df = pd.DataFrame([structured_tweets])

            if tweets_collection.empty:
                tweets_collection = reqd_df
            else:
                tweets_collection = tweets_collection.append(reqd_df)
    return tweets_collection

# %% [markdown]
# ### To save the output of the tweet-information into the categories, General or Italy

# %%
def save_output(tweets_collection, 
                curr_datetime,
                category="General", 
                subset="predictions"):
    if category in ["General", "Italy"]:
        file_name = 'relevant_{}_{}.csv'.format(subset, curr_datetime)
        tweets_collection.to_csv(
            os.path.join(tw_output_directory, category, file_name),
            index=False)
    else:
        print("Output Directory is not valid!")

# %%
def get_saved_versions(name, location):
    files = os.listdir(location)
    found_files = list()
    for f in files:
        match = re.search("({})\-(\d+)\.csv$".format(name), f)
        if match:
            f_groups = match.groups()
            saved_version = f_groups[-1]
            map_ = {"file": f, "version": int(saved_version)}
            found_files.append(map_)
    if found_files:
        versions_ = pd.DataFrame(found_files)
        return versions_
    else:
        return pd.DataFrame()


def save_output_version(data, name, location, version=None):
    filename_format = "{name}-{version}.csv"
    next_version = int(version) if version else 1
    all_versions = get_saved_versions(name, location)
    if not all_versions.empty:
        next_version = 1 + int(all_versions["version"].max())
        if version and version >= next_version:
            next_version = version
    new_name = filename_format.format(name=name, version=next_version)
    data.to_csv(os.path.join(location, new_name), index=False)
    return new_name

# %%
# get_saved_versions("it-it-tweets", os.path.join(tw_output_directory, "Italy"))
get_saved_versions("en-it-news", nh_output_directory)
# Out:
#                file  version
# 0  en-it-news-1.csv        1
# 1  en-it-news-2.csv        2

# %% [markdown]
# ## Deployed model

# %% [markdown]
# ### Endpoint URL to query the model in real time

# %%
enpoint_uri = "http://ac6a2064dee3c11e99ced0a13821e56d-733867741.ap-southeast-1.elb.amazonaws.com/sentiment/classifier"
headers = {"content-type": "application/json"}

# %% [markdown]
# ### Get polarity of a piece of text

# %%
def get_polarity(sentence):
    data = json.dumps({"polarity": sentence})
    response = requests.post(enpoint_uri, data=data, headers=headers)
    return response.json() if response.status_code == 200 else ""

# %% [markdown]
# ## Get and Process Tweets from a set of users

# %% [markdown]
# ### Get tweets posted by a list of users

# %%
user_specific_tweets = get_tweets(query_set=user_specific_queries)
# Out:
# No filter/Filter in query_set: ("early election") from:lorepregliasco -has:media
# No filter/Filter in query_set: ("early election") from:FerdiGiugliano -has:media
# No filter/Filter in query_set: ("early election") from:AlbertoNardelli -has:media
# No filter/Filter in query_set: ("early election") from:gavinjones10 -has:media
# No filter/Filter in query_set: ("snap election") from:lorepregliasco -has:media
# No filter/Filter in query_set: ("snap election") from:FerdiGiugliano -has:media
# No filter/Filter in query_set: ("snap election") from:AlbertoNardelli -has:media
# No filter/Filter in query_set: ("snap election") from:gavinjones10 -has:media
# No filter/Filter in query_set: ("government collapse") from:lorepregliasco -has:media
# No filter/Filter in query_set: ("government collapse") from:FerdiGiugliano -has:media
# No filter/Filter in query_set: ("government collapse") from:AlbertoNardelli -has:media
# No filter/Filter in query_set: ("government collapse") from:gavinjones10 -has:media

# %% [markdown]
# ### Process the tweets

# %%
user_tweets_collection = process_tweets(user_specific_tweets)
user_tweets_collection
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Clean the DataFrame of tweets

# %%
user_tweets_collection = user_tweets_collection.reset_index().drop(columns=['index'])
duplicacy_subset = list(set(user_tweets_collection.columns) - set(["created_time"]))
user_tweets_collection.drop_duplicates(subset=duplicacy_subset, inplace=True)
user_tweets_collection.dropna(subset=["text"])
# user_tweets_collection.dropna(subset=["text"])
# Out:
#            created_time  ...                                               text
# 0   2019-10-22 08:56:15  ...  Today in Rome, beautiful things! Inside Politi...
# 1   2019-10-22 08:50:23  ...  9619 train, stopped for half an hour in the tu...
# 2   2019-10-22 08:05:33  ...  Thank you, all right on board, but the 'delay'...
# 3   2019-10-22 07:57:54  ...  The saga will end, the story lives forever. Wa...
# 4   2019-10-22 07:55:39  ...          Beautiful things, this afternoon in Rome!
# 5   2019-10-22 07:46:41  ...  "Travel time 20 minutes longer than expected"....
# 6   2019-10-22 05:38:53  ...                                           Colleges
# 7   2019-10-22 05:00:05  ...  Liberals and Democrats (NDP) would currently l...
# 8   2019-10-22 04:47:43  ...  among the colleges to be assigned, the 2 most ...
# 9   2019-10-22 04:44:45  ...  For this it would be the definitive distributi...
# 10  2019-10-22 04:44:32  ...  assigned 331 seats out of 338. Here are those ...
# 11  2019-10-21 22:12:35  ...
# 12  2019-10-21 17:37:53  ...  I begin to have the feeling that the times of ...
# 13  2019-10-21 17:31:02  ...  Two other useful data on # Umbria. Policies 20...
# 14  2019-10-21 16:19:38  ...           zero also on Calabria and EmiliaRomagna?
# 15  2019-10-21 16:15:40  ...                            political consequences?
# 16  2019-10-21 16:05:54  ...                     But I don't say it for free! p
# 17  2019-10-21 15:42:31  ...  Three figures for the elections on Sunday. Reg...
# 18  2019-10-21 15:40:41  ...
# 19  2019-10-21 15:37:34  ...  On a Sunday night in the Langhe... I'll answer...
# 20  2019-10-21 15:26:06  ...                According to you how it will end in
# 21  2019-10-21 14:40:44  ...  Job offer for internships, apply! We are looki...
# 22  2019-10-21 12:27:31  ...  Urns open today for the renewal of Parliament!...
# 23  2019-10-21 06:37:22  ...  Fire at the Royal Cavallerizza of Turin, herit...
# 24  2019-10-20 21:54:28  ...  I booked for tonight in March. Anyway, I'll se...
# 25  2019-10-20 15:31:04  ...                                I would say Caletta
# 26  2019-10-20 14:26:42  ...  Damn you next year I'll be waiting for you at ...
# 27  2019-10-20 12:33:29  ...                                    If you knew ..!
# 28  2019-10-20 07:03:29  ...
# 29  2019-10-20 06:47:44  ...      On Sunday, listen to driving towards the sea.
# ..                  ...  ...                                                ...
# 880 2019-09-26 06:18:04  ...
# 881 2019-09-26 06:15:45  ...
# 882 2019-09-25 11:34:05  ...
# 883 2019-09-25 10:12:12  ...
# 884 2019-09-25 10:09:53  ...
# 885 2019-09-25 07:49:09  ...
# 886 2019-09-24 20:01:08  ...
# 887 2019-09-24 09:35:51  ...
# 888 2019-09-24 07:01:34  ...
# 889 2019-09-23 21:38:11  ...
# 890 2019-09-23 21:32:31  ...
# 891 2019-09-23 21:13:00  ...
# 892 2019-09-23 20:48:55  ...
# 893 2019-09-23 19:16:21  ...
# 894 2019-09-23 19:15:52  ...
# 895 2019-09-23 13:42:38  ...
# 896 2019-09-23 10:44:49  ...
# 897 2019-09-23 09:53:23  ...
# 898 2019-09-23 09:39:35  ...
# 899 2019-09-23 07:13:07  ...
# 900 2019-09-22 21:51:15  ...
# 901 2019-09-22 20:53:30  ...
# 902 2019-09-22 20:23:32  ...
# 903 2019-09-22 19:59:54  ...
# 904 2019-09-22 17:31:11  ...
# 905 2019-09-22 17:12:27  ...
# 906 2019-09-22 16:48:14  ...
# 907 2019-09-22 10:30:45  ...
# 908 2019-09-22 10:08:13  ...
# 909 2019-09-22 10:04:06  ...
#
# [910 rows x 5 columns]

# %% [markdown]
# ## Get and Process Tweets from Italy

# %% [markdown]
# ### Clean the DataFrame of tweets from Italy

# %%
italy_tweets_collection = italy_tweets_collection.reset_index().drop(columns=['index'])
duplicacy_subset = list(set(italy_tweets_collection.columns) - set(["created_time"]))
italy_tweets_collection.drop_duplicates(subset=duplicacy_subset, inplace=True)
italy_tweets_collection
# Out:
#                                                   text  ...        created_time
# 0    How will an early election stop us crashing ou...  ... 2019-10-27 10:07:35
# 1    People voted just a year and a half ago, there...  ... 2019-10-24 08:56:38
# 2    Elezioni anticipate I saw this on the BBC and ...  ... 2019-10-19 22:24:18
# 3    Appello I saw this on the BBC and thought you ...  ... 2019-11-14 06:47:18
# 4    Still waiting for a witness to state unequivoc...  ... 2019-11-13 19:40:41
# ..                                                 ...  ...                 ...
# 218  Governo di minoranza saw this on the BBC and t...  ... 2019-10-23 21:59:48
# 219  Big takeaway  electoral reform. You cannot hav...  ... 2019-10-22 07:55:28
# 220  Chance of a full blown coalition between Liber...  ... 2019-10-22 03:06:55
# 221  New Coalition Is Already Fighting Over Its Nex...  ... 2019-10-21 09:46:54
# 222  I predict a LiberalNDP coalition. The Liberals...  ... 2019-10-21 06:15:42
#
# [160 rows x 5 columns]

# %%
save_output_version(data=italy_tweets_collection,
                    name="en-it-tweets",
                    location=tw_output_directory)
# Out:
# 'en-it-tweets-1.csv'

# %% [markdown]
# ### Attach predictions of the tweets into the DataFrame

# %%
italy_tweets_collection["polarity_v1"] = italy_tweets_collection["text"].apply(get_polarity)

# %%
italy_tweets_collection
# Out:
#          created_time  ... polarity_v1
# 0 2019-10-19 22:24:18  ...    positive
# 0 2019-09-29 07:39:34  ...    positive
# 0 2019-09-29 07:25:09  ...    negative
#
# [3 rows x 6 columns]

# %% [markdown]
# ### Save output of the collection of tweets in Google Drive
# Folder location: https://drive.google.com/open?id=1iX7i_jarE7hhOVf68p-KzUECrEG59u4T

# %%
save_output(italy_tweets_collection, 
            category="Italy",
            subset="predictions", 
            curr_datetime=today())

# %% [markdown]
# ## Get generic tweets (relevant to the keywords)

# %% [markdown]
# ### Get all tweets that contain the keywords like *snap election*, *early election*, *political instability*

# %%
generic_tweets = get_tweets(queries, generic_query_filter)
# Out:
# Collecting for ("early election") -has:media
# Collecting for ("snap election") -has:media
# Collecting for ("government collapse") -has:media
# Collecting for ("government coalition") -has:media
# Collecting for ("election") -has:media
# Collecting for ("instability") -has:media
# Collecting for ("uncertainty") -has:media
# Collecting for ("crisis") -has:media
# Collecting for ("coalition") -has:media

# %% [markdown]
# ### Process all the generic tweets

# %%
generic_tweets_collection = process_tweets(generic_tweets)
# Out:
# clean_str = Salmond's November rape Trial could be a reason SNP may agree to an early election
# cleaner_str = Salmond's November rape Trial could be a reason SNP may agree to an early election
# clean_str = was weighing whether to push for an early or try again to pass his stalled after blocked a fast-track plan to approve his before...
# cleaner_str = was weighing whether to push for an early or try again to pass his stalled after blocked a fasttrack plan to approve his before...
# clean_str = Salmond's November rape Trial could be a reason SNP may agree to an early election
# cleaner_str = Salmond's November rape Trial could be a reason SNP may agree to an early election
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = A nation of Brendas? What the public really thinks of a general election
# cleaner_str = A nation of Brendas? What the public really thinks of a general election
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = Nice little piece from on the public's desire for an election, despite prevailing media consensus.
# cleaner_str = Nice little piece from on the public's desire for an election, despite prevailing media consensus.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = People want a general election. It's the political class who don't want to test their politics with the masses.
# cleaner_str = People want a general election. It's the political class who don't want to test their politics with the masses.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# cleaner_str = On this, v interesting piece which says that the public actually want a general election, those who don't are (generally) politicians and political journalists who think the public don't either.
# clean_str = This is what I suspect as well....it's now become a targeted nation wide movement to force early election if possible &amp; to drag down newly elected politicians instead of getting down the work of running this country I have to wonder if some Conservative premiers will spend the next four years stifling progress in their own provinces and blaming for it, simply to: 1. Get themselves re-elected 2. Elect a Con federal government
# cleaner_str = This is what I suspect as well....it's now become a targeted nation wide movement to force early election if possible & to drag down newly elected politicians instead of getting down the work of running this country I have to wonder if some Conservative premiers will spend the next four years stifling progress in their own provinces and blaming for it, simply to 1. Get themselves reelected 2. Elect a Con federal government
# clean_str = A nation of Brendas? What the public really thinks of a general election
# cleaner_str = A nation of Brendas? What the public really thinks of a general election
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = My latest prediction, for what it's worth: swings behind early election. Narrow win for Tories giving them majority to crash out without a deal in new year. vote split betw &amp; Please
# cleaner_str = My latest prediction, for what it's worth swings behind early election. Narrow win for Tories giving them majority to crash out without a deal in new year. vote split betw & Please
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = The British Parliament has blocked a fast-track plan to approve Boris Johnson's deal. Now Johnson has to decide whether to push for an early election or try to pass his stalled EU deal.
# cleaner_str = The British Parliament has blocked a fasttrack plan to approve Boris Johnson's deal. Now Johnson has to decide whether to push for an early election or try to pass his stalled EU deal.
# clean_str = The British Parliament has blocked a fast-track plan to approve Boris Johnson's deal. Now Johnson has to decide whether to push for an early election or try to pass his stalled EU deal.
# cleaner_str = The British Parliament has blocked a fasttrack plan to approve Boris Johnson's deal. Now Johnson has to decide whether to push for an early election or try to pass his stalled EU deal.
# clean_str = Did you actually watch it? Corbyn clear &amp; concise, Johnson dithering &amp; erring, clearly not on top of his brief! Thee more of this we get the more clearly voters will see Johnson for the lightweight he is! Which is why the Tories are pushing for an early election.
# cleaner_str = Did you actually watch it? Corbyn clear & concise, Johnson dithering & erring, clearly not on top of his brief! Thee more of this we get the more clearly voters will see Johnson for the lightweight he is! Which is why the Tories are pushing for an early election.
# clean_str = I think a bigger issue is if Labour doesn't agree to early election then by Spring voters are likely to have lost any faith they have. Politically the tactic might work but it would be another example of politicians treating the public with disdain and that can't go on.
# cleaner_str = I think a bigger issue is if Labour doesn't agree to early election then by Spring voters are likely to have lost any faith they have. Politically the tactic might work but it would be another example of politicians treating the public with disdain and that can't go on.
# clean_str = To clarify - the PM can't decide to hold an early election. He needs the support of two-thirds of MPs - at least 434 - this is a legal requirement, set out under the Fixed-term Parliaments Act
# cleaner_str = To clarify  the PM can't decide to hold an early election. He needs the support of twothirds of MPs  at least 434  this is a legal requirement, set out under the Fixedterm Parliaments Act
# clean_str = Setting aside a dramatic improvement in Liberal polls and Trudeau triggering an election, which other party stands to benefit from an early election and can afford another election? Without the per-vote subsidy, the smaller parties probably need time to fundraise.
# cleaner_str = Setting aside a dramatic improvement in Liberal polls and Trudeau triggering an election, which other party stands to benefit from an early election and can afford another election? Without the pervote subsidy, the smaller parties probably need time to fundraise.
# clean_str = To clarify - the PM can't decide to hold an early election. He needs the support of two-thirds of MPs - at least 434 - this is a legal requirement, set out under the Fixed-term Parliaments Act
# cleaner_str = To clarify  the PM can't decide to hold an early election. He needs the support of twothirds of MPs  at least 434  this is a legal requirement, set out under the Fixedterm Parliaments Act
# clean_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act - two thirds of MPs say yes - the election date is set by royal proclamation. That means the PM would set the date
# cleaner_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act  two thirds of MPs say yes  the election date is set by royal proclamation. That means the PM would set the date
# clean_str = Oh dear. It's not a matter of opinion: the PM cannot call an election whenever he wants. He tried and failed twice in September to get an early election FFS. Giant Brain Man cannot change the Fixed-term Parliaments Act.
# cleaner_str = Oh dear. It's not a matter of opinion the PM cannot call an election whenever he wants. He tried and failed twice in September to get an early election FFS. Giant Brain Man cannot change the Fixedterm Parliaments Act.
# clean_str = RisingNepal: UK prime minister mulls early election over Brexit... -
# cleaner_str = RisingNepal UK prime minister mulls early election over Brexit...
# clean_str = Britain's next scheduled election is in 2022.
# cleaner_str = Britain's next scheduled election is in 2022.
# clean_str = Britain's next scheduled election is in 2022.
# cleaner_str = Britain's next scheduled election is in 2022.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK: Johnson mulls early election over Brexit impasse
# cleaner_str = UK Johnson mulls early election over Brexit impasse
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = Britain's next scheduled election is in 2022.
# cleaner_str = Britain's next scheduled election is in 2022.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = Britain's next scheduled election is in 2022.
# cleaner_str = Britain's next scheduled election is in 2022.
# clean_str = Downing Street believes calling an early election is the best way forward.
# cleaner_str = Downing Street believes calling an early election is the best way forward.
# clean_str = Which makes me think that an early election would be a great idea
# cleaner_str = Which makes me think that an early election would be a great idea
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = If EU offer an extension to date X, we are always going to have the issue that the government could, through the provisions for early election in the FTPA, move the GE date beyond date X. Therefore No Deal will never be off the table unless open ended extension or GE date fixed.
# cleaner_str = If EU offer an extension to date X, we are always going to have the issue that the government could, through the provisions for early election in the FTPA, move the GE date beyond date X. Therefore No Deal will never be off the table unless open ended extension or GE date fixed.
# clean_str = Richard Burgon confirms on that as soon as an extension is offered beyond Oct 31st Labour will back an early election. He calls the referendum before election idea as "fantasy politics".
# cleaner_str = Richard Burgon confirms on that as soon as an extension is offered beyond Oct 31st Labour will back an early election. He calls the referendum before election idea as "fantasy politics".
# clean_str = He's got every call wrong so far, from the progation, to the early election, to the whip withdrawals
# cleaner_str = He's got every call wrong so far, from the progation, to the early election, to the whip withdrawals
# clean_str = Considering Labour can effectively indefinitely veto an early election in the Commons it's absolutely not true
# cleaner_str = Considering Labour can effectively indefinitely veto an early election in the Commons it's absolutely not true
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = British Prime Minister Boris Johnson was weighing Wednesday whether to push for an early election or try again to pass his stalled European Union divorce deal,...
# cleaner_str = British Prime Minister Boris Johnson was weighing Wednesday whether to push for an early election or try again to pass his stalled European Union divorce deal,...
# clean_str = Final hurdle in the Commons cleared! Third reading passes 327 v 299 Hope the Lords will deal with it efficiently so we can get it into law as soon as possible Now debate on early election - a trap PM trying to set which opposition parties won't support - he's got to own this
# cleaner_str = Final hurdle in the Commons cleared! Third reading passes 327 v 299 Hope the Lords will deal with it efficiently so we can get it into law as soon as possible Now debate on early election  a trap PM trying to set which opposition parties won't support  he's got to own this
# clean_str = British PM Boris Johnson mulls early election over stalled Brexit deal
# cleaner_str = British PM Boris Johnson mulls early election over stalled Brexit deal
# clean_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act - two thirds of MPs say yes - the election date is set by royal proclamation. That means the PM would set the date
# cleaner_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act  two thirds of MPs say yes  the election date is set by royal proclamation. That means the PM would set the date
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = UK prime minister mulls early election over Brexit impasse.
# cleaner_str = UK prime minister mulls early election over Brexit impasse.
# clean_str = Oh dear. It's not a matter of opinion: the PM cannot call an election whenever he wants. He tried and failed twice in September to get an early election FFS. Giant Brain Man cannot change the Fixed-term Parliaments Act.
# cleaner_str = Oh dear. It's not a matter of opinion the PM cannot call an election whenever he wants. He tried and failed twice in September to get an early election FFS. Giant Brain Man cannot change the Fixedterm Parliaments Act.
# clean_str = Nice work, so still a loss, Well hopefully minority government will result in a early election, and we have another kick at the can
# cleaner_str = Nice work, so still a loss, Well hopefully minority government will result in a early election, and we have another kick at the can
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = To clarify - the PM can't decide to hold an early election. He needs the support of two-thirds of MPs - at least 434 - this is a legal requirement, set out under the Fixed-term Parliaments Act
# cleaner_str = To clarify  the PM can't decide to hold an early election. He needs the support of twothirds of MPs  at least 434  this is a legal requirement, set out under the Fixedterm Parliaments Act
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act - two thirds of MPs say yes - the election date is set by royal proclamation. That means the PM would set the date
# cleaner_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act  two thirds of MPs say yes  the election date is set by royal proclamation. That means the PM would set the date
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act - two thirds of MPs say yes - the election date is set by royal proclamation. That means the PM would set the date
# cleaner_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act  two thirds of MPs say yes  the election date is set by royal proclamation. That means the PM would set the date
# clean_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act - two thirds of MPs say yes - the election date is set by royal proclamation. That means the PM would set the date
# cleaner_str = If MPs vote for an early election under the two thirds route in the fixed term parliaments act  two thirds of MPs say yes  the election date is set by royal proclamation. That means the PM would set the date
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = UK prime minister mulls early election over Brexit impasse
# cleaner_str = UK prime minister mulls early election over Brexit impasse
# clean_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# cleaner_str = I would love there to be an election before Xmas so I can ride off into the sunset after briefly explaining myself to my constituents. But I think it would be grossly irresponsible to vote for an early election while there is a chance that Parliament might pass the Brexit deal.
# clean_str = That's democracy. Isn't every party pretty much committed to an early election before 2022 anyway? So we will all presumably have the chance to express our views again, once MPs who say they want a public vote actually vote for one.
# cleaner_str = That's democracy. Isn't every party pretty much committed to an early election before 2022 anyway? So we will all presumably have the chance to express our views again, once MPs who say they want a public vote actually vote for one.
# clean_str = Richard Burgon confirms on that as soon as an extension is offered beyond Oct 31st Labour will back an early election. He calls the referendum before election idea as "fantasy politics".
# cleaner_str = Richard Burgon confirms on that as soon as an extension is offered beyond Oct 31st Labour will back an early election. He calls the referendum before election idea as "fantasy politics".
# ...
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse
# clean_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse twitter in 2019 is waking up and checking if the british or us government or both collapsed while u were sleeping
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Pre Twitter was waking up and checking if Britain or the US made your government collapse twitter in 2019 is waking up and checking if the british or us government or both collapsed while u were sleeping
# clean_str = D'Amico used to sell a AR-15-style rifle with coordinates on the receiver. In the event of a massive disaster or government collapse, owners of the rifle could follow the coordinates to D'Amico's compound, and show it at the front gate to get access.
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = D'Amico used to sell a AR15style rifle with coordinates on the receiver. In the event of a massive disaster or government collapse, owners of the rifle could follow the coordinates to D'Amico's compound, and show it at the front gate to get access.
# clean_str = Amiti 1996 NTR government collapse marchipoyara brother, 1999 elections marchipoyara Charitra teliyadha telusukondi,antheylendi mana yellow media rayadhu ,Manam migilanivi chudam
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str = Amiti 1996 NTR government collapse marchipoyara brother, 1999 elections marchipoyara Charitra teliyadha telusukondi,antheylendi mana yellow media rayadhu ,Manam migilanivi chudam
# clean_str = Agora Inc Predicts a total banking and government collapse - In 40 years they have never been wrong:
# Exception occurred: 403 POST https://translation.googleapis.com/language/translate/v2: User Rate Limit Exceeded
# cleaner_str =
# 1315 2019-09-27 11:05:23  ...  I get tired of watching my government collapse...
# 1420 2019-09-27 08:23:31  ...  Pre Twitter was waking up and checking if Brit...
# 1421 2019-09-26 17:40:13  ...  D'Amico used to sell a AR15style rifle with co...
# 1422 2019-09-26 02:47:13  ...  Amiti 1996 NTR government collapse marchipoyar...
# 1424 2019-09-25 17:27:55  ...  Harper 12 years period, go back what reality d...
# 1425 2019-09-25 14:44:01  ...  just got off a flight did the government colla...
# 1426 2019-09-25 11:20:05  ...  Also prepared for aliens, an outbreak of a dis...
# 1427 2019-09-25 07:04:03  ...  Yet another minister who needs to resign. The ...
# 1428 2019-09-25 01:46:50  ...  Impeachment relevant Destruction of society Go...
# 1429 2019-09-24 23:24:36  ...  Was he gonna just let Ukraine's government col...
# 1433 2019-09-24 16:24:14  ...    Tax returns before complete government collapse
# 1436 2019-09-24 14:02:59  ...               Government Collapse Celebration Bike
# 1437 2019-09-23 01:08:24  ...  Probably it is the beginning of Moon governmen...
#
# [422 rows x 5 columns]

# %% [markdown]
# ### Save the generic Twitter results to Google Drive

# %%
save_output(generic_tweets_collection, subset="tweets", curr_datetime=today())

# %% [markdown]
# ### Merge the predictions of tweets in the DataFrame

# %%
generic_tweets_collection["polarity_v1"] = generic_tweets_collection["text"].apply(get_polarity)

# %% [markdown]
# ### Save the predicted generic tweets in Google Drive
# Folder location: https://drive.google.com/open?id=13FRvvDetM4Bcsdw9dblKuEr9Tyz219_A

# %%
save_output(generic_tweets_collection, 
            subset="predictions", 
            curr_datetime=today())

# %% [markdown]
# ## Fetch tweets (en-it, it-it)

# %% [markdown]
# ### Get and save tweets specific to the country of origin (English)

# %%
en_it_tweets = get_tweets(queries, it_query_filter)
en_it_tweets_collection = process_tweets(en_it_tweets)
en_it_tweets_collection = en_it_tweets_collection.reset_index().drop(columns=['index'])
duplicacy_subset = list(set(en_it_tweets_collection.columns) - set(["created_time"]))
en_it_tweets_collection.drop_duplicates(subset=duplicacy_subset, inplace=True)
en_it_tweets_collection
# Out:
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("early election") -has:media place_country:IT
# 0
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7306
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7306
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("snap election") -has:media place_country:IT
# 0
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7306
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7306
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("government collapse") -has:media place_country:IT
# 0
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7306
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7306
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("government coalition") -has:media place_country:IT
# 0
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7306
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7306
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("election") -has:media place_country:IT
# 100
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7406
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7406
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7406
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7406
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7406
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("instability") -has:media place_country:IT
# 4
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7406
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7410
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7410
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7410
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7410
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7410
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("uncertainty") -has:media place_country:IT
# 2
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7410
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7412
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7412
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7412
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7412
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7412
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("crisis") -has:media place_country:IT
# 100
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7412
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7512
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7512
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7512
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7512
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7512
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("coalition") -has:media place_country:IT
# 11
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7512
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7523
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7523
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7523
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7523
# clean_str = Just days after Sri Lanka's election, hundreds of investigators into the ruling Rajapaksa family are banned from leaving the country, and a Swiss Embassy employee is abducted and asked about asylum applications Just days after Sri Lanka's election, hundreds of investigators into the ruling Rajapaksa family are banned from leaving the country, and a Swiss Embassy employee is abducted and asked about asylum applications
# clean_str = The most unpredictable election ever? Don't believe it
# cleaner_str = The most unpredictable election ever? Don't believe it
# clean_str = Seems like he was busy with the election campaign
# cleaner_str = Seems like he was busy with the election campaign
# clean_str = !!! !!! FREEDOM-FAKER, BORIS, BINS TAX CUTS, as his ROAD TO NOWHERE STARTS WITH A U-TURN !!!
# cleaner_str = !!! !!! FREEDOMFAKER, BORIS, BINS TAX CUTS, as his ROAD TO NOWHERE STARTS WITH A UTURN !!!
# clean_str = Is election u are talking about oooo
# cleaner_str = Is election u are talking about oooo
# clean_str = Corteggiare il mondo economico I saw this on the BBC and thought you should see it: General election 2019: Leaders woo business with tax and apprenticeship vows -
# cleaner_str = Corteggiare il mondo economico I saw this on the BBC and thought you should see it General election 2019 Leaders woo business with tax and apprenticeship vows
# clean_str = BBC News - General election 2019: Conservatives promise 'equal' immigration system
# cleaner_str = BBC News  General election 2019 Conservatives promise 'equal' immigration system
# clean_str = Vedremo cosa accadra I saw this on the BBC and thought you should see it: election: Wartime defence chief Rajapaksa wins presidency -
# cleaner_str = Vedremo cosa accadra I saw this on the BBC and thought you should see it election Wartime defence chief Rajapaksa wins presidency
# clean_str = !!! HE KNOWS ITS FAUX !!! promises to UNBLOCK parliament -- even though this KNOWS that BLOCKAGE is not the problem: THAT is his own, deal, to which only offer solution !!!
# cleaner_str = !!! HE KNOWS ITS FAUX !!! promises to UNBLOCK parliament  even though this KNOWS that BLOCKAGE is not the problem THAT is his own, deal, to which only offer solution !!!
# clean_str = They should continue to create criminals as Your Excellency bcos they want to dominate the political scene. Shame, sham election, mock election. Others are moving forward, Nigeria is moving backward.
# cleaner_str = They should continue to create criminals as Your Excellency bcos they want to dominate the political scene. Shame, sham election, mock election. Others are moving forward, Nigeria is moving backward.
# clean_str = !!! !!! has put BREXIT and COUNTRY BEFORE PARTY -- unlike VAIN BORIS, and his LITTLE EGO that could COST LEAVE SEATS by standing -- pointlessly and destructively -- against !!!
# cleaner_str = !!! !!! has put BREXIT and COUNTRY BEFORE PARTY  unlike VAIN BORIS, and his LITTLE EGO that could COST LEAVE SEATS by standing  pointlessly and destructively  against !!!
# clean_str = Ah, but it's ok because it's only the BBC that's required to be an impartial &amp; fair political news broadcaster during an election, right?
# cleaner_str = Ah, but it's ok because it's only the BBC that's required to be an impartial & fair political news broadcaster during an election, right?
# clean_str = Secondo mandato I saw this on the BBC and thought you should see it: Democrat wins governor election in Louisiana -
# cleaner_str = Secondo mandato I saw this on the BBC and thought you should see it Democrat wins governor election in Louisiana
# clean_str = Una vittoria chiara di una figura controversa I saw this on the BBC and thought you should see it: Sri Lanka election: Ex-defence chief Rajapaksa set to win vote -
# cleaner_str = Una vittoria chiara di una figura controversa I saw this on the BBC and thought you should see it Sri Lanka election Exdefence chief Rajapaksa set to win vote
# clean_str = "Most importantly, they need to break the cycle of amplifying disinformation by 'covering the controversy.'"
# cleaner_str = "Most importantly, they need to break the cycle of amplifying disinformation by 'covering the controversy.'"
# clean_str = "Most of the attention in the battle against foreign disinformation has focused on bots, trolls and other digital actors on social media, but it must also include traditional media organizations."
# cleaner_str = The electoral threshold for the Estonian Parliament is 5%. It could be a thing, but I suppose that R would rather form a coalition government with SDE and E200 (if the polls are right)
# clean_str = But just out of curiosity why SSLP is at the same time right and left? Is it actually a coalition?
# cleaner_str = But just out of curiosity why SSLP is at the same time right and left? Is it actually a coalition?
# clean_str = Global Coalition to Defeat ISIS weighs next steps via
# cleaner_str = Global Coalition to Defeat ISIS weighs next steps via
# clean_str = I don't believe the will support a 2nd referendum if there is a chance of going into coalition with the party.
# cleaner_str = I don't believe the will support a 2nd referendum if there is a chance of going into coalition with the party.
# clean_str = !!! Need coalition with Tories to keep Brexit free. Overall Tory majority will create lingering fetters to EU.
# cleaner_str = !!! Need coalition with Tories to keep Brexit free. Overall Tory majority will create lingering fetters to EU.
# clean_str = !!! BLIND !!! ERG Tories CAN'T SEE that HUNG PARLIAMENT and coalition will SAVE CLEAN BREXIT from BOJO'S MAY-STYLE FUDGE !!!
# cleaner_str = !!! BLIND !!! ERG Tories CAN'T SEE that HUNG PARLIAMENT and coalition will SAVE CLEAN BREXIT from BOJO'S MAYSTYLE FUDGE !!!
# clean_str = There will be no pacts because 1) Swinson spends more time attacking Corbyn than Johnson 2) The Lib Dems itching for another Tory led coalition. Lib Dems stand no chance where I am but as a Labour voter I can't vote tactically for them when my vote will go indirectly to Tories
# cleaner_str = There will be no pacts because 1) Swinson spends more time attacking Corbyn than Johnson 2) The Lib Dems itching for another Tory led coalition. Lib Dems stand no chance where I am but as a Labour voter I can't vote tactically for them when my vote will go indirectly to Tories
#                                                   text  ...        created_time
# 0    Just days after Sri Lanka's election, hundreds...  ... 2019-11-28 05:45:35
# 1    So this isn't true is it then? It shows what t...  ... 2019-11-27 19:02:45
# 2    Oh please, They had an impeachment hearing fil...  ... 2019-11-27 07:23:30
# 3    Xiang and Kung were referred to the Taipei Dis...  ... 2019-11-26 20:42:37
# 4    !!! ISN'T IT IRONIC ??? Boris' selfdeprication...  ... 2019-11-26 18:40:59
# ..                                                 ...  ...                 ...
# 212  Global Coalition to Defeat ISIS weighs next st...  ... 2019-11-14 07:24:09
# 213  I don't believe the will support a 2nd referen...  ... 2019-11-11 20:02:06
# 214  !!! Need coalition with Tories to keep Brexit ...  ... 2019-11-07 08:06:42
# 215  !!! BLIND !!! ERG Tories CAN'T SEE that HUNG P...  ... 2019-11-03 22:46:27
# 216  There will be no pacts because 1) Swinson spen...  ... 2019-10-29 07:40:18
#
# [163 rows x 5 columns]

# %%
save_output_version(data=en_it_tweets_collection,
                    name="en-it-tweets",
                    location=tw_output_directory)
# Out:
# 'en-it-tweets-3.csv'

# %% [markdown]
# ### Get and save tweets from Italy (Italian)

# %%
it_it_tweets = get_tweets(queries_it, it_query_filter)
it_it_tweets_collection = process_tweets(it_it_tweets)
it_it_tweets_collection = it_it_tweets_collection.reset_index().drop(columns=['index'])
duplicacy_subset = list(set(it_it_tweets_collection.columns) - set(["created_time"]))
it_it_tweets_collection.drop_duplicates(subset=duplicacy_subset, inplace=True)
it_it_tweets_collection
# Out:
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6953
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("elezioni anticipate") -has:media place_country:IT
# 12
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6953
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    6965
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6965
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6965
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 6965
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6965
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("elezioni anticipate") -has:media place_country:IT
# 12
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6965
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    6977
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 6977
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("collasso del governo") -has:media place_country:IT
# 0
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    6977
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 6977
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("coalizione di governo") -has:media place_country:IT
# 3
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6977
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    6980
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6980
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6980
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 6980
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6980
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("elezione") -has:media place_country:IT
# 81
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     6980
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7061
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7061
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7061
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7061
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7061
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("instabilità") -has:media place_country:IT
# 21
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7061
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7082
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7082
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7082
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7082
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7082
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("incertezza") -has:media place_country:IT
# 24
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7082
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7106
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7106
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7106
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7106
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7106
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("crisi") -has:media place_country:IT
# 100
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7106
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7206
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7206
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7206
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7206
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7206
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Collecting for ("coalizione") -has:media place_country:IT
# 100
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7206
# ['2019-10-01T00:00:00.000Z', '2019-11']
# ['2019-10-01T00:00:00.000Z', '2019-11']
# Month present
#
# api_usage = 0    7306
# Name: 2019-11, dtype: int64
# Updating new API usage...
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
#    2019-10-01T00:00:00.000Z  2019-11
# 0                     24000     7306
# ['2019-10-01T00:00:00.000Z', '2019-11']
# API usage count updated! Current usage: 7306
# clean_str = On. Dimentica che Bettini ha:1) teorizzato la "scissione consensuale" 2) minaccia elezioni anticipate( come fece nel 2008)pensando di spaventare Ora le chiedo: che fine ha fatto l'area liberal del
# cleaner_str = On. Forget that Bettini has1) theorized the "consensual splitting" 2) threatens early elections (as he did in 2008) thinking of scaring. Now I ask you what happened to the liberal area of the
# clean_str = Bravo hai ridotto questo incapace ma furbetto una larva. Voleva far saltare il governo col pd per fare elezioni anticipate per poi rifare accordo con . ora lo hai commissariato come dici tu..."standogli vicino di piu che in passato"..
# cleaner_str = Bravo you reduced this incapable but cunning a larva. He wanted to blow up the government with the pd to make early elections and then make a new deal with. now you have the police station as you say ... "standogli near more than in the past" ..
# clean_str = Tutta questa folla e per le elezioni anticipate.
# cleaner_str = All this crowd and for early elections.
# clean_str = La Lega vede le elezioni anticipate sempre piu vicine
# cleaner_str = The League sees the early elections coming closer and closer
# clean_str = Ennesima barzelletta !!!! I parlamentari del M5S essendo una massa di disoccupati scappati di casa non faranno MAI cadere il governo per andare alle elezioni anticipate !!!!!
# cleaner_str = Yet another joke !!!! The M5S parliamentarians being a mass of unemployed people who have run away from home will NEVER drop the government to go to early elections !!!!!
# clean_str = In votano la 4^volta in 4 anni.CHE PERICOLOSI SOVVERSIVI!SONO MALATI DI DEMOCRAZIA!COME MAI?
# cleaner_str = They vote the 4th time in 4 years. WHAT HAZARDOUS SUBSCRIBERS ARE DISEASES OF DEMOCRACY! HOW NEVER?
# clean_str = In votano la 4^volta in 4 anni.PERICOLOSI SOVVERSIVI! SI OSTINANO CON LA DEMOCRAZIA!
# cleaner_str = They vote the 4th time in 4 years. YOU KEEP WITH DEMOCRACY!
# clean_str = No, con elezioni anticipate avremmo avuto il volere della stragrande maggioranza degli Italiani !!!!
# cleaner_str = No, with early elections we would have had the will of the vast majority of Italians !!!!
# clean_str = Scusi quali voti? Per caso qualcuno ha fatto delle liste di probabili candidati in caso di elezioni anticipate? Sa invece quanti avrebbero votato per Boccia o Franceschini?
# clean_str = E se in un'altra regione vince la sinistra che si va ad elezioni anticipate tutte le volte?Il Governo centrale deve dare stabilita al Paese.
# cleaner_str = And if the left wins in another region that you go to early elections all the time? The central government must give the country stability.
# clean_str = "Trasformare uno stato dissociativo in una coalizione di governo"
# cleaner_str = "Transform a dissociative state into a governing coalition"
# clean_str = Conte non fa altro che il suo dovere: parlare e dare solidarieta. In concreto, non e lui a decidere il "da farsi", ma alla coalizione di Governo, che sappiamo essere latitante in tutto.
# cleaner_str = Conte does nothing but his duty to speak and give solidarity. In concrete terms, it is not he who decides what to do, but the government coalition, which we know is a fugitive in everything.
# clean_str = Ernesto Preatoni: Cinquantasette a trentasette, quasi venti punti di differenza. E il risultato delle elezioni locali, in Umbria, che hanno visto il centrodestra rifilare quello che una volta si sarebbe definito "cappotto" all'attuale coalizione di governo giallo verde.
# cleaner_str = Ernesto Preatoni Fifty-seven to thirty-seven, almost twenty points of difference. And the result of the local elections, in Umbria, which saw the center-right trim what would once have been called a "coat" with the current yellow-green coalition of government.
# clean_str = Tranquillo , polvere sono e polvere ritorneranno. Le elezioni ,qualsiasi elezione, li spazzera via
# cleaner_str = Quiet, dust is and dust will come back. The elections, any election, will wipe them out
# clean_str = Madonna mi salvo 'sto tweet e giuro che alla prossima elezione torno a cagarti in testa. Promesso
# cleaner_str = Madonna saved my tweet and I swear that at the next election I go back to shitting my head. promised
# clean_str = Non ci credo per nulla. Questi si rivettano alle poltrone almeno fino all'elezione del nuovo PdR.
# cleaner_str = I don't believe it at all. These rivets to the seats at least until the election of the new PdR.
# clean_str = Fino al 1996 (quando Giovanni Paolo II ha abolito l'elezione per acclamazione) anch'io potevo sognare di diventare Papa. Bastava essere battezzati, maschi e non sposati. Vuoi mettere Mauritius primus?
# cleaner_str = Until 1996 (when John Paul II abolished the election by acclamation) I too could dream of becoming a Pope. It was enough to be baptized, male and unmarried. Do you want to put Mauritius primus?
# clean_str = art.27,co.2,Costituzione afferma che <<l'imputato non e considerato colpevole sino alla condanna definitiva>>.Se non si cambia la COSTITUZIONE imponendo ELEZIONE DEI PROCURATORI,come in USA,ci sara sempre un intreccio incestuoso tra politica e magistratura.
# cleaner_str = art.27, co.2, Constitution states that < <l'imputato non e considerato colpevole sino alla condanna definitiva> > .If you do not change the CONSTITUTION by imposing ELECTION OF PROCURATORS, as in the USA, there will always be an incestuous intertwining of politics and the judiciary.
# clean_str = art.27,co.2, della Costituzione afferma che <<l'imputato non e considerato colpevole sino alla condanna definitiva>>.Se non si cambia la COSTITUZIONE imponendo ELEZIONE DEI PROCURATORI,come in USA,ci sara sempre un intreccio incestuoso tra politica e magistratura
# cleaner_str = art.27, co.2, of the Constitution states that < <l'imputato non e considerato colpevole sino alla condanna definitiva> > .If you do not change the CONSTITUTION by imposing ELECTION OF PROCURATORS, as in the USA, there will always be an incestuous interweaving between politics and the judiciary
# clean_str = Eletta la nuova Auguri di buon lavoro Piu e per tutti, si spera. Elezione in diretta su
# cleaner_str = New best wishes for good work elected More and hopefully for everyone. Election live on
# clean_str = La coalizione tra i 5s e il PD e sempre sembrata una pessima idea. Sarebbe stato meglio concedere a Salvini il voto: quasi sicuramente avrebbe vinto, ma almeno avrebbe dovuto sottoporsi alla prova di governare da solo.
# cleaner_str = The coalition between the 5s and the PD has always seemed a bad idea. It would have been better to have granted Salvini the vote would almost certainly have won, but at least he would have had to undergo the test of governing alone.
# clean_str = .@emsclancy : "Casa e politiche abitative, accolte le proposte di Coalizione Civica"
# cleaner_str = . @ emsclancy "Housing and housing policies, accepted the proposals of Civic Coalition"
# clean_str = la regola della DEMOCRAZIA e semplice: chi raggiunge il 50%+1 vince e governa.E chiaro,logico e razionale che quel"chi"deve essere un partito o coalizione(formata PRIMA del voto).Alleanze innaturali"DOPO"collassano.Che si aspetta ad andare al voto?
# cleaner_str = the rule of DEMOCRACY is simple who reaches 50% + 1 wins and governs. It is clear, logical and rational that that "who" must be a party or coalition (formed BEFORE the vote). Unnatural alliances "AFTER" collapse. wait to go to the vote?
# clean_str = FINE DEL CENTRODESTRA. ITALIANI ECCO A VOI L'ANIMA DELLA COALIZIONE SALVINI MELONI BERLUSCONI : ESTREMA DESTRA POPULISTA SOVRANISTA FASCISTOIDE. Spariti i moderati, quel voto e la fine del centrodestra | Rep
# cleaner_str = END OF CENTRODESTRA. ITALIANI HERE YOU HAVE THE SOUL OF THE SALVINI MELONI BERLUSCONI COALITION EXTREME RIGHT POPULIST SOVRANIST FASCISTOID. The moderates disappeared, that vote and the end of the center-right | Rep
# clean_str = dalle 20:30 alle 23:00 Sala gruppo consigliare Coalizione Civica - Piazza Maggiore Assemblea Gruppo Salute di CC
# cleaner_str = from 2030 to 2300 group room advise Civic Coalition Piazza Maggiore Assembly Group of Health of CC
# clean_str = Questo e un odiatore seriale Marattin ed e della tua coalizione. I Pidioti del e quelli di ItaliaMorta di vogliono estirpare l'odio...
# cleaner_str = This is a serial hater from Marattin and from your coalition. The Pidioti of and those of ItaliaMorta want to eradicate hatred ...
# clean_str = Mara 'sta sindrome di Stoccolma finira mai? comunque stai in un partito e in una coalizione di collaborazionisti. cosi, per dire. spiace.
# cleaner_str = Mara 'is Stockholm syndrome going to end? however you are in a party and in a coalition of collaborators. just saying. sorry.
# clean_str = =&gt; coalizione tra ala carfagnana di Centrodestra e Italia Viva.
# cleaner_str = => coalition between the Carrodagnana wing of Centrodestra and Italia Viva.
# clean_str = Salute a te e a tutta la coalizione cdx con brindisi. Prossimo brindisi per l'Emilia Romagna. A presto Alla tua Matteo
# cleaner_str = Greetings to you and to the whole CDX coalition with a toast. Next toast for Emilia Romagna. See you soon
# clean_str = Il voto al di una grande vergogna sulla proposta E la dimostrazione che nel Paese non vi e piu una coalizione di centro destra, bensi, una destra pura e fascista. Chapeau e tanti saluti ai pochi moderati di cdx rimasti. La Senatrice che rimane sconvolta dal fatto che nemmeno la lotta alla violenza e alle discriminazioni incontri il parere unanime favorevole del Senato, e il segno della deriva razzista che questo paese ha intrapreso. Solo una parole: che schifo!
# cleaner_str = Li the only strong point and the governor Bonaccini, appreciated by many, who enjoys a high personal satisfaction but discounting the fact of having behind a coalition nothing short of weak and a party hated by all, if I'm not mistaken. Or am I wrong?
# clean_str = Avete forse sentito qualche TV parlare di questo?Eppure Berlusconi fa parte della coalizione che ha vinto in Umbria...o no
# cleaner_str = Have you heard any TV talk about this, yet Berlusconi is part of the coalition that won in Umbria ... or not
# clean_str = Report diventa la ennesima bocca da fuoco di una coalizione al tubo dell'ossigeno e che cerca nei sempre piu' screditati media un appoggio al quale ormai ben pochi danno ascolto
# cleaner_str = Report becomes the umpteenth firearm of a coalition to the oxygen tube and that seeks support in the increasingly discredited media to which very few now listen
# clean_str = Ernesto Preatoni: Cinquantasette a trentasette, quasi venti punti di differenza. E il risultato delle elezioni locali, in Umbria, che hanno visto il centrodestra rifilare quello che una volta si sarebbe definito "cappotto" all'attuale coalizione di governo giallo verde.
# cleaner_str = Ernesto Preatoni Fifty-seven to thirty-seven, almost twenty points of difference. And the result of the local elections, in Umbria, which saw the center-right trim what would once have been called a "coat" with the current yellow-green coalition of government.
# clean_str = In questo momento non credo ci sia coalizione o candidato capace di battere Tranne fallo governare.... Quindi screenshottate a piu nln posso che poi ci si diverte
# cleaner_str = At the moment I don't think there is a coalition or a candidate capable of beating Except let it govern ... So screenshottate to more nln I can then have fun
# clean_str = E se date queste premesse e corretto dire di un partito o di una coalizione " il partito delle tasse "?
# cleaner_str = And if you give these premises and correct to say of a party or a coalition "the tax party"?
# clean_str = Il Grande Vecchio ha fatto la scelta giusta, quello di preservare il cdx e stare ai patti. Chi a piu voti e il leader del cdx. Sta ora a Forza Italia rafforzarsi nella coalizione per avere piu peso
# cleaner_str = The Grande Vecchio has made the right choice, to preserve the CDX and keep to terms. Who with the most votes and the leader of the cdx. It is now up to Forza Italia to strengthen itself in the coalition to gain more weight
#                                                   text  ...        created_time
# 0    On. Forget that Bettini has1) theorized the "c...  ... 2019-11-27 12:59:14
# 1    Bravo you reduced this incapable but cunning a...  ... 2019-11-23 12:32:30
# 2              All this crowd and for early elections.  ... 2019-11-15 21:29:19
# 3    The League sees the early elections coming clo...  ... 2019-11-15 15:51:24
# 4    Yet another joke !!!! The M5S parliamentarians...  ... 2019-11-13 08:33:51
# ..                                                 ...  ...                 ...
# 347  Have you heard any TV talk about this, yet Ber...  ... 2019-10-29 21:28:33
# 348  Report becomes the umpteenth firearm of a coal...  ... 2019-10-29 19:33:46
# 350  At the moment I don't think there is a coaliti...  ... 2019-10-29 16:27:06
# 351  And if you give these premises and correct to ...  ... 2019-10-29 14:36:38
# 352  The Grande Vecchio has made the right choice, ...  ... 2019-10-29 11:21:57
#
# [250 rows x 5 columns]

# %%
save_output_version(data=it_it_tweets_collection,
                    name="it-it-tweets",
                    location=os.path.join(tw_output_directory, "Italy"))
# Out:
# 'it-it-tweets-3.csv'

# %% [markdown]
# ## Collect Data

# %% [markdown]
# ### Correct Headers of files with inconsistent column names

# %%
def file_valid(file_path):
    if os.path.isfile(file_path):
        if re.search(".*\.csv$", file_path):
            return file_path
    return ""


def correct_files(file_collection):
    for filename in file_collection:
        if filename:
            df = pd.read_csv(filename, encoding="utf-8")
            df.rename(columns={df.columns[0]: "text"}, 
                    inplace=True)
            df.to_csv(filename, index=False)


files_to_correct = [f for f in map(lambda s:
    file_valid(os.path.join(tw_output_directory, s)),
    os.listdir(tw_output_directory))]

correct_files(files_to_correct)

# file_ = pd.read_csv(os.path.join(tw_output_directory, 
#                                  "relevant_tweets_output_2.csv"),
#                     encoding="utf-8")
# file_.rename(columns={"headline_text": "text"}, inplace=True)
# file_

# %% [markdown]
# ### Fetch en-it News Headlines

# %%
en_fresh_headlines = fetch_news(queries, news_sources)
if not en_fresh_headlines.empty:
    en_news_collection = en_fresh_headlines.reset_index().drop(columns=["index"])
    en_news_collection.to_csv(os.path.join(nh_output_directory, 
                                        "news_{}.csv".format(today())),
                            index=False)
    print("en_news_collection")
    print(en_news_collection.columns)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Updating new API usage...
# API usage count updated! Current usage: 0
# Updating new API usage...
# API usage count updated! Current usage: 1
# Updating new API usage...
# API usage count updated! Current usage: 2
# Updating new API usage...
# API usage count updated! Current usage: 3
# Updating new API usage...
# API usage count updated! Current usage: 4
# Updating new API usage...
# API usage count updated! Current usage: 5
# Updating new API usage...
# API usage count updated! Current usage: 6
# Updating new API usage...
# API usage count updated! Current usage: 0
# Updating new API usage...
# API usage count updated! Current usage: 1
# en_news_collection
# Index(['author', 'title', 'description', 'url', 'urlToImage', 'publishedAt',
#        'source'],
#       dtype='object')

# %%
save_output_version(data=en_news_collection, 
                    name="en-it-news", 
                    location=nh_output_directory)
# Out:
# 'en-it-news-3.csv'

# %% [markdown]
# ### Fetch it-it News Headlines

# %%
fresh_headlines = fetch_news(queries_it, news_sources)
if not fresh_headlines.empty:
    it_news_collection = fresh_headlines.reset_index().drop(columns=["index"])
    it_news_collection.to_csv(os.path.join(nh_output_directory, 
                                        "news_{}.csv".format(today())),
                            index=False)
    print("it_news_collection")
    print(it_news_collection.columns)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/strings.py:1843: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Updating new API usage...
# API usage count updated! Current usage: 2
# Updating new API usage...
# API usage count updated! Current usage: 3
# Updating new API usage...
# API usage count updated! Current usage: 4
# Updating new API usage...
# API usage count updated! Current usage: 5
# Updating new API usage...
# API usage count updated! Current usage: 6
# Updating new API usage...
# API usage count updated! Current usage: 7
# Updating new API usage...
# API usage count updated! Current usage: 8
# Updating new API usage...
# API usage count updated! Current usage: 9
# it_news_collection
# Index(['author', 'title', 'description', 'url', 'urlToImage', 'publishedAt',
#        'source'],
#       dtype='object')

# %%
save_output_version(data=it_news_collection, 
                    name="it-it-news", 
                    location=nh_output_directory)
# Out:
# 'it-it-news-3.csv'

# %% [markdown]
# ### Collect and combine previously saved and fresh data from Twitter and NewsAPI (and also from Firebolt)

# %%
def get_previous_data(file_loc, column_list=None):
    # file_name = ""
    # file_loc = os.path.join(DRIVE_LOCATION, PREV_DATA_DIR, file_name)
    prev_data = pd.read_csv(file_loc)
    if not prev_data.empty:
        return prev_data[column_list] if column_list else prev_data
    return None


def get_fresh_data(tweets, headlines):
    processed_tweets = None
    news_collection = None
    if tweets:
        fresh_data = dict()
        # get fresh tweets:
        # tweets = get_tweets(queries, query_filter)
        processed_tweets = process_tweets(tweets)
        processed_tweets = processed_tweets.reset_index().drop(
            columns=['index'])
        print("processed_tweets")
        print(processed_tweets.columns)
        duplicacy_subset = list(
            set(processed_tweets.columns) - {"created_time"})
        processed_tweets.drop_duplicates(subset=duplicacy_subset, inplace=True)
        processed_tweets.to_csv(os.path.join(tw_output_directory, 
                                             "tweets_{}.csv".format(today())),
                                index=False)
    # get fresh news headlines:
    # headlines = fetch_news(queries, sources, ...)
    if not headlines.empty:
        news_collection = headlines.reset_index().drop(columns=["index"])
        news_collection.to_csv(os.path.join(nh_output_directory, 
                                            "news_{}.csv".format(today())),
                               index=False)
        print("news_collection")
        print(news_collection.columns)
    fresh_data["tweets"] = processed_tweets
    fresh_data["headlines"] = news_collection
    return fresh_data


def frame_files(files):
    final_df = pd.DataFrame()
    for f in files:
        if os.path.exists(f) and os.path.isfile(f):
            inter_df = pd.read_csv(f, encoding="UTF-8")
            final_df = final_df.append(inter_df)
    return final_df


def combine_data_offline(tweets_files, news_files, prev_files_map=None):
    processed_headlines = processed_tweets = prev_data_df = pd.DataFrame()
    # tweets_files = "it-it-tweets" if not tweets_files else tweets_files
    # news_files = "it-it-news" if not news_files else news_files

    if prev_files_map:
        for filename, column in prev_files_map.items():
            file_df = get_previous_data(filename, column)
            print("prev_data = {}".format(file_df.shape))
            if prev_data_df.empty:
                prev_data_df = file_df
            else:
                prev_data_df = prev_data_df.append(file_df)
        print("combined prev_data = {}".format(prev_data_df.shape))
        prev_data_df = prev_data_df.reset_index().drop(columns=["index"])
        print("post-reset prev_data = {}".format(prev_data_df.shape))
        prev_data_df.rename(columns={prev_data_df.columns[0]: "text"}, 
                            inplace=True)
        prev_data_df.drop_duplicates(inplace=True)
        print("post-removing duplicates prev_data = {}".format(prev_data_df.shape))
    print("final prev_data = {}".format(prev_data_df.shape))
    
    tw_text = nh_text = list()
    saved_tweets = get_saved_versions(tweets_files["type"], 
                                      tweets_files["path"])
    print("\nFetching it-it Tweets")
    if not saved_tweets.empty:
        tweets_ = list(saved_tweets["file"])
        processed_tweets = pd.DataFrame()
        for tweet_ in tweets_:
            print("reading {}".format(os.path.join(tweets_files["path"], tweet_)))
            df_ = pd.read_csv(os.path.join(tweets_files["path"], tweet_),
                              encoding="UTF-8")
            print("{}: shape = {}".format(tweet_, df_.shape))
            processed_tweets = processed_tweets.append(df_)
        if not processed_tweets.empty:
            tw_text = list(processed_tweets["text"])
    print("len(tw_text): {}".format(len(tw_text)))
    
    saved_news = get_saved_versions(news_files["type"], news_files["path"])
    print("\nFetching it-it News Headlines")
    if not saved_news.empty:
        news_ = list(saved_news["file"])
        processed_headlines = pd.DataFrame()
        for headline_ in news_:
            print("reading {}".format(os.path.join(news_files["path"], headline_)))
            df_ = pd.read_csv(os.path.join(news_files["path"], headline_),
                              encoding="UTF-8")
            print("{}: shape = {}".format(headline_, df_.shape))
            processed_headlines = processed_headlines.append(df_)
        if not processed_headlines.empty:
            nh_text = list(processed_headlines["url"])
    print("len(nh_text): {}".format(len(nh_text)))
    tw_text.extend(nh_text)
    if not prev_data_df.empty:
        base_ = list(prev_data_df["text"])
        base_.extend(tw_text)
    else:
        base_ = tw_text
    print("len(base_): {}".format(len(base_)))
    final_df = pd.DataFrame(base_, columns=["data"])
    final_df.drop_duplicates(inplace=True)
    return final_df


def combine_data(prev_files):
    prev_data_df = pd.DataFrame()
    for filename, column in prev_files.items():
        file_df = get_previous_data(filename, column)
        if prev_data_df.empty:
            prev_data_df = file_df
        else:
            prev_data_df = prev_data_df.append(file_df)
    prev_data_df = prev_data_df.reset_index().drop(columns=["index"])
    prev_data_df.rename(columns={prev_data_df.columns[0]: "text"}, inplace=True)
    prev_data_df.drop_duplicates(inplace=True)
    # return prev_data_df
    # get fresh data
    twitter_keywords = queries
    selected_filter = it_query_filter
    tweets = get_tweets(twitter_keywords, selected_filter)
    news_keywords = twitter_keywords
    # news_sources = []
    headlines = fetch_news(news_keywords, news_sources)
    fresh_data = get_fresh_data(tweets, headlines)
    combined_data = prev_data_df.append(fresh_data["tweets"]["text"]).append(
        fresh_data["headlines"]["url"])
    return combined_data

# %%
tweets_files_it = {"type": "it-it-tweets", 
                "path": os.path.join(tw_output_directory, "Italy")}
news_files_it = {"type": "it-it-news", 
                "path": nh_output_directory}
search_results_path = os.path.join(DRIVE_LOCATION, 
                                   "Search-Results-{}.csv".format(
                                       today().split("_")[0]))
search_results_map = {search_results_path: "link"}
search_combined_it_it = combine_data_offline(tweets_files_it, 
                                              news_files_it,
                                              search_results_map)
search_combined_it_it["rating"] = ""
# Out:
# prev_data = (105,)
# combined prev_data = (105,)
# post-reset prev_data = (105, 1)
# post-removing duplicates prev_data = (105, 1)
# final prev_data = (105, 1)
#
# Fetching it-it Tweets
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/it-it-tweets-1.csv
# it-it-tweets-1.csv: shape = (160, 5)
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/it-it-tweets-2.csv
# it-it-tweets-2.csv: shape = (282, 5)
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/it-it-tweets-3.csv
# it-it-tweets-3.csv: shape = (250, 5)
# len(tw_text): 692
#
# Fetching it-it News Headlines
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/it-it-news-1.csv
# it-it-news-1.csv: shape = (86, 7)
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/it-it-news-2.csv
# it-it-news-2.csv: shape = (86, 7)
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/it-it-news-3.csv
# it-it-news-3.csv: shape = (77, 7)
# len(nh_text): 249
# len(base_): 1046

# %%
search_combined_it_it.to_csv(
    os.path.join(DRIVE_LOCATION, "it-it", "Data-Collection-{}-v1.csv".format(
        today_date
    )), 
    index=False)

# %%
tweets_files_it = {"type": "it-it-tweets", 
                "path": os.path.join(tw_output_directory, "Italy")}
news_files_it = {"type": "it-it-news", 
                "path": nh_output_directory}
offline_combined_it_it = combine_data_offline(tweets_files_it, news_files_it)
# Out:
# final prev_data = (0, 0)
#
# Fetching it-it Tweets
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/it-it-tweets-1.csv
# it-it-tweets-1.csv: shape = (160, 5)
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/it-it-tweets-2.csv
# it-it-tweets-2.csv: shape = (282, 5)
# len(tw_text): 442
#
# Fetching it-it News Headlines
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/it-it-news-1.csv
# it-it-news-1.csv: shape = (86, 7)
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/it-it-news-2.csv
# it-it-news-2.csv: shape = (86, 7)
# len(nh_text): 172
# len(base_): 614
#                                                   data
# 0    How will an early election stop us crashing ou...
# 1    People voted just a year and a half ago, there...
# 2    Elezioni anticipate I saw this on the BBC and ...
# 3    Appello I saw this on the BBC and thought you ...
# 4    Still waiting for a witness to state unequivoc...
# ..                                                 ...
# 569  http://www.ansa.it/sito/notizie/economia/2019/...
# 584  http://www.ansa.it/sito/notizie/topnews/2019/1...
# 608  http://www.ansa.it/sito/notizie/topnews/2019/1...
# 610  http://www.ansa.it/sito/notizie/topnews/2019/1...
# 611  http://www.ansa.it/campania/notizie/2019/11/15...
#
# [522 rows x 1 columns]

# %%
offline_combined_it_it.to_csv(
    os.path.join(DRIVE_LOCATION, "it-it", "Data-Collection-{}.csv".format(
        today_date
    )), 
    index=False)

# %%
tweets_files_en = {"type": "en-it-tweets", 
                "path": tw_output_directory}
news_files_en = {"type": "en-it-news", 
                "path": nh_output_directory}
offline_combined_en_it = combine_data_offline(tweets_files_en, news_files_en)
offline_combined_en_it
# Out:
# final prev_data = (0, 0)
#
# Fetching it-it Tweets
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/en-it-tweets-1.csv
# en-it-tweets-1.csv: shape = (160, 5)
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/en-it-tweets-2.csv
# en-it-tweets-2.csv: shape = (114, 5)
# reading /gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/en-it-tweets-3.csv
# en-it-tweets-3.csv: shape = (163, 5)
# len(tw_text): 437
#
# Fetching it-it News Headlines
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/en-it-news-1.csv
# en-it-news-1.csv: shape = (220, 7)
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/en-it-news-2.csv
# en-it-news-2.csv: shape = (226, 7)
# reading /gdrive/My Drive/Political Risk Project/Test Data/News Results/en-it-news-3.csv
# en-it-news-3.csv: shape = (229, 7)
# len(nh_text): 675
# len(base_): 1112
#                                                    data
# 0     How will an early election stop us crashing ou...
# 1     People voted just a year and a half ago, there...
# 2     Elezioni anticipate I saw this on the BBC and ...
# 3     Appello I saw this on the BBC and thought you ...
# 4     Still waiting for a witness to state unequivoc...
# ...                                                 ...
# 1097  https://www.reuters.com/article/us-yemen-secur...
# 1099  https://www.reuters.com/article/us-spain-polit...
# 1102  https://www.reuters.com/article/us-yemen-secur...
# 1105  https://www.reuters.com/article/us-ethiopia-po...
# 1109  https://www.reuters.com/article/us-slovakia-po...
#
# [573 rows x 1 columns]

# %%
offline_combined_en_it.to_csv(
    os.path.join(DRIVE_LOCATION, "en-it", "Data-Collection-{}-v2.csv".format(
        today().split("_")[0]
    )), 
    index=False)

# %%
# prev_files = dict()
# prev_files.extend(os.listdir(nh_output_directory))

def get_prev_files():
    dir_col_map = {tw_output_directory: "text",
                   nh_output_directory: "url",
                   search_results: "link"
                   }
    prev_files = dict()

    def extract_csv_files(directory, source):
        # files_ = list()
        if os.path.isdir(directory):
            for part in os.listdir(directory):
                # print(part)
                if os.path.isdir(os.path.join(directory, part)):
                    extract_csv_files(os.path.join(directory, part), source)
                else:
                    if re.search(".*\.csv$", part) and \
                    part not in prev_files.keys():
                        prev_files[os.path.join(directory, part)] = source
        elif os.path.isfile(directory):
            if re.search(".*\.csv$", directory) \
            and directory not in prev_files.keys():
                prev_files[directory] = source
    
    for directory, column in dir_col_map.items():
        extract_csv_files(directory, column)
    
    return prev_files


get_prev_files()
# extract_csv_files(tw_output_directory, "text")
# extract_csv_files(nh_output_directory, "url")
# extract_csv_files(search_results, "link")
# print(prev_files)
# combine_data(prev_files)
# Out:
# {'/gdrive/My Drive/Firebolt/Political Risk/new_outputs.csv': 'link',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/News Headlines Predictions/newsheadlines_predictions_2019-10-24_05-40.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/all_results.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/all_results_new.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/en-it-news-1.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/everything_on_early_election.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/everything_on_government_collapse.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/everything_on_political_instability.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/everything_on_snap_election.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/it-it-news-1.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/news_2019-11-11_11-41.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/news_2019-11-14_10-37.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/News Results/news_2019-11-14_10-41.csv': 'url',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/General/relevant_predictions_2019-10-22_11-35.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/General/relevant_predictions_2019-10-23_16-35.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/General/relevant_tweets_2019-10-22 10-18.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/General/relevant_tweets_2019-10-23_16-26.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/it-it-tweets-1.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/relevant_predictions_2019-10-22_12-36.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/Italy/relevant_predictions_2019-10-23_16-15.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/en-it-tweets-1.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/general_tweets_2019-10-21 09-39.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/relevant_tweets.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/relevant_tweets_output_2.csv': 'text',
#  '/gdrive/My Drive/Political Risk Project/Test Data/Twitter Results/tweets_2019-11-11_11-41.csv': 'text'}

# %% [markdown]
# ### Combine Offline Data

# %%
# text_data = combine_data_offline(prev_files)
# collection = pd.DataFrame(text_data)
# collection["rating"] = ""
# Out:
#                                                    data
# 0     Where now for Brexit  Johnson's WAB cd pass bu...
# 1     That's nothing. I got MPs to vote on an early ...
# 2     Yes vote workers rights away,then lets have an...
# 3     I'm sure that I speak for a large number of Ca...
# 4     If parliament does pass a Brexit deal this wee...
# ...                                                 ...
# 3183  https://www.reuters.com/article/us-mideast-cri...
# 3184  https://www.reuters.com/article/us-north-maced...
# 3185  https://www.reuters.com/article/us-germany-pol...
# 3186  https://www.reuters.com/article/us-internet-ta...
# 3187  https://www.reuters.com/article/us-arcelormitt...
#
# [3188 rows x 1 columns]

# %%
collection.drop_duplicates(subset=["data"], inplace=True)

# %%
collection.to_csv(os.path.join(
    DRIVE_LOCATION, "DataCollection_{}.csv".format(today())), 
                  index=False)

# %% [markdown]
# ## Redundant cells:

# %%
# tweets_data = pd.DataFrame(tweets)
# tweets_data
# print(tweets_data.loc[0]["text"])

# all_texts = [{"all_text": structure_text(t.all_text), 
#               "created_at": extract_datetime_string(t.created_at_datetime)}
#               for t in tweets]
# all_texts
# for tweet in tweets:
#     print(dir(tweet))

# %%
# str_ = ["Beyoncé necesita ver esto. Que diosa @TiniStoessel 🔥🔥🔥 https://t.co/gadVJbehQZ", 
#         "When Beyoncé adopts a dog 🙌🏾 https://t.co/U571HyLG4F",
#         "Yup!!!! ❤️❤️❤️❤️ #davechappelle https://t.co/ybSGNrQpYF"]

# c = [clean_str for clean_str in map(remove_emojis, str_)]
# s1 = "Beyoncé necesita ver esto. Que diosa"
# s1 = "Yup!!!! ❤️❤️❤️❤️ #davechappelle #love https://t.co/ybSGNrQpYF"
# s1 += "@davarch1 @PKBook22 @davarch1 @TheStephenRalph https://t.co/gadVJbehQZ https://t.co/gadVJbehQZ https://t.co/U571HyLG4F"

# %%
# # detect_language(" ".join(['Un', 'voto', 'importante', 'con', 'incognite']))
# s1 = "Un voto importante con incognite di coalizione I saw this on the BBC and thought you should see it: votes in snap election after video sting scandal"
# # translate_keyword(" ".join(['Un', 'voto', 'importante', 'con', 'incognite']), "en")
# s1_arr = s1.split(" ")
# non_english = dict()
# for index, token in enumerate(s1_arr):
#     if detect_language(token) != "en":
#         non_english.update({index: token})

# # remaining_eng = s1_arr[list(non_english.keys())[-1]+1:]
# non_eng_text = " ".join(list(non_english.values()))
# translated_non_eng = translate_keyword(non_eng_text)
# s1t = s1.replace(non_eng_text, translated_non_eng)
# # list(non_english.keys())
# italian_tweets = pd.DataFrame(all_texts)
# italian_tweets
# # italian_tweets.to_csv(os.path.join(output_directory, 
# #                                    "italian_tweets_{}.csv".format(today)),
# #                       index=False)

# %%
# text_ = """This piece of text is taken from http://ansa.it. Una lunga maratona notturna sblocca l'impasse del governo sulla legge di bilancio e il decreto fiscale. Arriva il via libera salvo intese. Alle cinque del mattino, dopo un Consiglio dei ministri di quasi sei ore, il premier Giuseppe Conte e il ministro dell'Economia Roberto Gualtieri si mostrano stanchi ma soddisfatti: arriva una manovra da circa 30 miliardi, con lo stop all'aumento dell'Iva, tre miliardi per tagliare le tasse ai lavoratori, 600 milioni per la famiglia, la fine del superticket da settembre 2020 e il piano di lotta all'evasione Italia cashless voluto da Conte."""
# sample_text = re.split(r'\.\s+', text_)

# clean_tweets = [row for row in map(structure_text, sample_text)]
# # for tweet_row in clean_tweets:
# #     ix = clean_tweets.index(tweet_row)
# #     text = tweet_row["text"]
# #     lang = detect_language(text)
# #     if lang != "en":
# #         translated_text = unescape(
# #             translate_keyword(text, "en"))
# #         clean_tweets[ix]["text"] = translated_text
# pd.DataFrame(clean_tweets, index=None)

# %%
# # query = '("early election" OR "snap election OR government collapse") {}'.format(query_filter)
# query_2 = '("government collapse") {}'.format(query_filter)
# # query_url = parse.quote(query)

# %%
# def structure_text(entire_str):
#     separations = dict()
#     clean_str = remove_emojis(entire_str)
#     tokens, links, handles, tags = extract_components(clean_str)
#     clean_str = (" ".join(tokens)).strip()
#     print("clean_str = {}".format(clean_str))
#     cleaner_str = (re.subn("[:-]+", "", clean_str))[0].strip()
#     cleaner_str_split = cleaner_str.split(" ")
#     non_english = dict()
#     try:
#         for index, token in enumerate(cleaner_str_split):
#             if detect_language(token) != "en":
#                 non_english.update({index: token})
#         if non_english:
#             print("non_english: {}".format(non_english))
#             non_eng_text = " ".join(list(non_english.values()))
#             translated_non_eng = unescape(translate_keyword(non_eng_text))
#             cleaner_str = cleaner_str.replace(non_eng_text, translated_non_eng)
#     except Exception as e:
#         print("Exception occurred: {}".format(e))
#         cleaner_str = ""
#     print("cleaner_str = {}".format(cleaner_str))
#     separations['text'] = cleaner_str
#     separations['links'] = ",".join(links)
#     separations['handles'] = ",".join(handles)
#     separations['tags'] = ",".join(tags)
#     return separations

# %%
# def process_tweets(tweets_list):
#     tweets_collection = pd.DataFrame()
#     for tweets in tweets_list:
#         for tweet in tweets:
#             structured_tweets = structure_text(tweet.all_text)
#             structured_tweets.update({"created_time":tweet.created_at_datetime})
#             reqd_df = pd.DataFrame([structured_tweets])
#             # reqd_df.drop_duplicates(inplace=True)
#             # reqd_df["text"] = reqd_df["text"].apply(
#             #     lambda s: re.subn('(\s)', ' ', s)[0])
#             # reqd_df["text"] = reqd_df["text"].apply(structure_text)
#             # match_str = '({})'.format(query)
#             if tweets_collection.empty:
#                 tweets_collection = reqd_df
#             else:
#                 tweets_collection = tweets_collection.append(reqd_df)
#     # tweets_collection.drop_duplicates(inplace=True)
#     return tweets_collection

# %%
# rule = gen_rule_payload(query, results_per_call=100)
# r = gen_rule_payload(query_2, results_per_call=100)

# %%
# tweets_2 = collect_results(r,
#                          max_results=500,
#                          result_stream_args=premium_search_args)

# %%
# len(tweets_2)

# %%
# [print(tweet.all_text, end='\n\n') for tweet in tweets_2[0:10]]

# %%
# tweets_data = pd.DataFrame(tweets)

# %%
# type(tweets[3]["quoted_status"]) == type({})
# tweets_data_2

# %%
# nested_columns = []
# for tweet in tweets[:2]:
#     print("tweet {}".format(tweets.index(tweet)))
#     for col in tweet.keys():
        
#         if tweet[col] and (type(tweet[col]) == type({}) or type(tweet[col]) == type([])):
#             print("\tcolumn: {}\tvalue: {}".format(col, tweet[col]))

# %%
# # all_text = tweets_data["text"].drop_duplicates()
# all_text = pd.Series([tweet.all_text for tweet in tweets])
# all_text.drop_duplicates(inplace=True)

# %%
# # import codecs
# # codecs.getdecoder("unicode_escape")(all_text.loc[8])[0]
# all_text_2

# %%
# all_text_refined = all_text.apply(lambda s: re.subn('(\s)', ' ', s)[0])

# %%
# all_text_refined.loc[454]

# %%
# match_str = '(government collapse)'
# reqd_df = all_text_refined[all_text_refined.str.contains(match_str)]
# # reqd_df.drop_duplicates(subset=['headline_text'], inplace=True)

# %%
# reqd_df_2

# %%
# def combine_data_offline(tweets_files, news_files, prev_files_map=None):
#     processed_headlines = processed_tweets = prev_data_df = pd.DataFrame()
    
#     if prev_files_map:
#         for filename, column in prev_files_map.items():
#             file_df = get_previous_data(filename, column)
#             if prev_data_df.empty:
#                 prev_data_df = file_df
#             else:
#                 prev_data_df = prev_data_df.append(file_df)
#         prev_data_df = prev_data_df.reset_index().drop(columns=["index"])
#         prev_data_df.rename(columns={prev_data_df.columns[0]: "text"}, 
#                             inplace=True)
#         prev_data_df.drop_duplicates(inplace=True)
#     processed_tweets = pd.read_csv(os.path.join(tw_output_directory,
#                                                 "tweets_2019-11-11_11-41.csv"),
#                                    encoding="UTF-8")
    
#     tw_text = list(processed_tweets["text"])
#     processed_headlines = pd.read_csv(os.path.join(nh_output_directory, 
#                                           "news_2019-11-11_11-41.csv"),
#                              encoding="UTF-8")
#     nh_text = list(processed_headlines["url"])
#     tw_text.extend(nh_text)
#     if not prev_data_df.empty:
#         base_ = list(prev_data_df["text"])
#         base_.extend(tw_text)
#     else:
#         base_ = tw_text
#     final_df = pd.DataFrame(base_, columns=["data"])
#     return final_df
